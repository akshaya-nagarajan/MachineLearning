# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaya-nagarajan/MachineLearning/blob/master/MLNewsArticle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/MLSpring2020/"
base_dir = root_dir + 'the_expendables_AirQuality_Traffic/Alternus_vera/'
# Out:
# Mounted at /content/gdrive

# %%
jsonFile = base_dir+"News_Category_Dataset.json"

# %%
# !pip3 install newspaper3k

# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime

# %%
LIMIT = 2

# %%
data = {}
data['newspapers'] = {}

# %%
jsonFile
# Out:
# '/content/gdrive/My Drive/MLSpring2020/the_expendables_AirQuality_Traffic/Alternus_vera/News_Category_Dataset.json'

# %%
with open(jsonFile) as data_file:
    jsonList = json.load(data_file)

# %%
count = 1
for value in jsonList:
    print("Downloading articles from ", value['link'])
    paper = newspaper.build(value['link'], memoize_articles=False)
    newsPaper = {
        "link": value['link'],
        "articles": []
    }
    for content in paper.articles:
        if count > LIMIT:
            break
        try:
            content.download()
            content.parse()
        except Exception as e:
            continue
        article = {}
        article['title'] = content.title
        article['text'] = content.text
        article['link'] = content.url
        article['author'] = content.authors
        newsPaper['articles'].append(article)
        if count % 10 == 0: 
            print(count, "articles downloaded from using newspaper, url: ", content.url)
        count = count + 1
    count = 1
# Out:
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-410b9c53d8fd> in <module>()
#       2 for value in jsonList:
#       3     print("Downloading articles from ", value['link'])
# ----> 4     paper = newspaper.build(value['link'], memoize_articles=False)
#       5     newsPaper = {
#       6         "link": value['link'],
#
# /usr/local/lib/python3.6/dist-packages/newspaper/api.py in build(url, dry, config, **kwargs)
#      28     s = Source(url, config=config)
#      29     if not dry:
# ---> 30         s.build()
#      31     return s
#      32
#
# /usr/local/lib/python3.6/dist-packages/newspaper/source.py in build(self)
#      96         self.parse_categories()
#      97
# ---> 98         self.set_feeds()
#      99         self.download_feeds()  # mthread
#     100         # self.parse_feeds()
#
# ...

# %%
newsPaper
# Out:
# {'articles': [{'author': ['Marina Velasco',
#     'Eduardo Loren',
#     'Uxía Prieto',
#     'Courtney Leiva',
#     'Elena Santos',
#     'Elena Niño',
#     'Redacción El Huffpost',
#     'Pablo Machuca'],
#    'link': 'https://www.huffingtonpost.es/feature/coronavirus/',
#    'text': 'Inscríbase al boletín\n\nEl HuffPost\n\n¿Quieres que no se te pase nada? Recibe cada día lo más importante de la actualidad. Y los sábados, los mejores virales y artículos culturales.',
#    'title': 'Coronavirus: Última hora en El HuffPost'},
#   {'author': ['Lorena G. Díaz', 'Periodista Y Viajera.'],
#    'link': 'https://www.huffingtonpost.es/news/destacados/',
#    'text': '¿Quieres que no se te pase nada? Recibe cada día lo más importante de la actualidad. Y los sábados, los mejores virales y artículos culturales. Los boletines pueden contener contenido o publicidad personalizada. Quiero saber más',
#    'title': 'Destacados'}],
# ...
